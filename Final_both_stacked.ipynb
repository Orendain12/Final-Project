# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to change the path if needed.)
cause_data_to_load = "causes_of_death.csv"
prevalence_data_to_load = "U.S._Chronic_Disease_Indicators_v2.csv"

# %%
cause_data_df = pd.read_csv(cause_data_to_load)
prevalence_data_df = pd.read_csv(prevalence_data_to_load)
cause_data_df.head()
# Out:
#    Year                                     Cause Name 113  \
# 0  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 1  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 2  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 3  2017  Accidents (unintentional injuries) (V01-X59,Y8...
# 4  2017  Accidents (unintentional injuries) (V01-X59,Y8...
#
#                Cause Name          State  Deaths  Death Rate
# 0  Unintentional injuries  United States  169936        49.4
# 1  Unintentional injuries        Alabama    2703        53.8
# 2  Unintentional injuries         Alaska     436        63.7
# 3  Unintentional injuries        Arizona    4184        56.2
# 4  Unintentional injuries       Arkansas    1625        51.8

# %%
cause_data_df = cause_data_df.drop(columns ='Cause Name 113')
cause_data_df
# Out:
#        Year              Cause Name          State  Deaths  Death Rate
# 0      2017  Unintentional injuries  United States  169936        49.4
# 1      2017  Unintentional injuries        Alabama    2703        53.8
# 2      2017  Unintentional injuries         Alaska     436        63.7
# 3      2017  Unintentional injuries        Arizona    4184        56.2
# 4      2017  Unintentional injuries       Arkansas    1625        51.8
# ...     ...                     ...            ...     ...         ...
# 10863  1999          Kidney disease       Virginia    1035        16.9
# 10864  1999          Kidney disease     Washington     278         5.2
# 10865  1999          Kidney disease  West Virginia     345        16.4
# 10866  1999          Kidney disease      Wisconsin     677        11.9
# 10867  1999          Kidney disease        Wyoming      30         6.8
#
# [10868 rows x 5 columns]

# %%
cause_data_df.to_csv('cause_data.csv')

# %%
prevalence_data_df
# Out:
#      YearStart LocationDesc DataSource                   Topic  \
# 0         2015       Alaska      BRFSS  Chronic Kidney Disease
# 1         2015      Alabama      BRFSS  Chronic Kidney Disease
# 2         2015     Arkansas      BRFSS  Chronic Kidney Disease
# 3         2015      Arizona      BRFSS  Chronic Kidney Disease
# 4         2015   California      BRFSS  Chronic Kidney Disease
# ..         ...          ...        ...                     ...
# 905       2015      Wyoming      BRFSS                 Tobacco
# 906       2012      Wyoming      BRFSS                 Tobacco
# 907       2011      Wyoming      BRFSS                 Tobacco
# 908       2014      Wyoming      BRFSS                 Tobacco
# 909       2013      Wyoming      BRFSS                 Tobacco
#
#           Adj Topic                                           Question  \
# 0    Kidney Disease  Prevalence of chronic kidney disease among adu...
# ...

# %%
prevalence_data_df = prevalence_data_df.drop(columns = 'Topic')
prevalence_data_df
# Out:
#      YearStart LocationDesc DataSource       Adj Topic  \
# 0         2015       Alaska      BRFSS  Kidney Disease
# 1         2015      Alabama      BRFSS  Kidney Disease
# 2         2015     Arkansas      BRFSS  Kidney Disease
# 3         2015      Arizona      BRFSS  Kidney Disease
# 4         2015   California      BRFSS  Kidney Disease
# ..         ...          ...        ...             ...
# 905       2015      Wyoming      BRFSS         Tobacco
# 906       2012      Wyoming      BRFSS         Tobacco
# 907       2011      Wyoming      BRFSS         Tobacco
# 908       2014      Wyoming      BRFSS         Tobacco
# 909       2013      Wyoming      BRFSS         Tobacco
#
#                                               Question  Response  \
# 0    Prevalence of chronic kidney disease among adu...       NaN
# 1    Prevalence of chronic kidney disease among adu...       NaN
# 2    Prevalence of chronic kidney disease among adu...       NaN
# ...

# %%
prevalence_data_df = prevalence_data_df.drop(columns = 'DataSource')
prevalence_data_df
# Out:
#      YearStart LocationDesc       Adj Topic  \
# 0         2015       Alaska  Kidney Disease
# 1         2015      Alabama  Kidney Disease
# 2         2015     Arkansas  Kidney Disease
# 3         2015      Arizona  Kidney Disease
# 4         2015   California  Kidney Disease
# ..         ...          ...             ...
# 905       2015      Wyoming         Tobacco
# 906       2012      Wyoming         Tobacco
# 907       2011      Wyoming         Tobacco
# 908       2014      Wyoming         Tobacco
# 909       2013      Wyoming         Tobacco
#
#                                               Question  Response  \
# 0    Prevalence of chronic kidney disease among adu...       NaN
# 1    Prevalence of chronic kidney disease among adu...       NaN
# 2    Prevalence of chronic kidney disease among adu...       NaN
# 3    Prevalence of chronic kidney disease among adu...       NaN
# 4    Prevalence of chronic kidney disease among adu...       NaN
# ...

# %%
prevalence_data_df = prevalence_data_df.drop(columns = 'Response')
prevalence_data_df
# Out:
#      YearStart LocationDesc       Adj Topic  \
# 0         2015       Alaska  Kidney Disease
# 1         2015      Alabama  Kidney Disease
# 2         2015     Arkansas  Kidney Disease
# 3         2015      Arizona  Kidney Disease
# 4         2015   California  Kidney Disease
# ..         ...          ...             ...
# 905       2015      Wyoming         Tobacco
# 906       2012      Wyoming         Tobacco
# 907       2011      Wyoming         Tobacco
# 908       2014      Wyoming         Tobacco
# 909       2013      Wyoming         Tobacco
#
#                                               Question DataValueUnit  \
# 0    Prevalence of chronic kidney disease among adu...             %
# 1    Prevalence of chronic kidney disease among adu...             %
# 2    Prevalence of chronic kidney disease among adu...             %
# 3    Prevalence of chronic kidney disease among adu...             %
# 4    Prevalence of chronic kidney disease among adu...             %
# ...

# %%
prevalence_data_df = prevalence_data_df.drop(columns = 'DataValueAlt')
prevalence_data_df
# Out:
#      YearStart LocationDesc       Adj Topic  \
# 0         2015       Alaska  Kidney Disease
# 1         2015      Alabama  Kidney Disease
# 2         2015     Arkansas  Kidney Disease
# 3         2015      Arizona  Kidney Disease
# 4         2015   California  Kidney Disease
# ..         ...          ...             ...
# 905       2015      Wyoming         Tobacco
# 906       2012      Wyoming         Tobacco
# 907       2011      Wyoming         Tobacco
# 908       2014      Wyoming         Tobacco
# 909       2013      Wyoming         Tobacco
#
#                                               Question DataValueUnit  \
# 0    Prevalence of chronic kidney disease among adu...             %
# 1    Prevalence of chronic kidney disease among adu...             %
# 2    Prevalence of chronic kidney disease among adu...             %
# 3    Prevalence of chronic kidney disease among adu...             %
# 4    Prevalence of chronic kidney disease among adu...             %
# ...

# %%
prevalence_data_df.to_csv('prevalence_data.csv')
